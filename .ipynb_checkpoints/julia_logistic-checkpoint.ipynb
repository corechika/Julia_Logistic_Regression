# %%
function sigmoid(x)
    return 1 / (1 + exp(-x))
end
# Out:
# sigmoid (generic function with 1 method)

# %%
function f(x1, w)
    # 決定境界の直線の方程式
    # p(C1|X) > 0.5 -> XをC1に分類
    # p(C1|X) < 0.5 -> XをC2に分類
    # 次元は全部同じなので，"./"などは不要
    a = - (w[2] / w[3])
    b = - (w[1] / w[3])
    return a * x1 + b
end
# Out:
# f (generic function with 1 method)

# %% [markdown]
# ## 訓練データ作成と学習

# %%
using Distributions
using Plots
using LinearAlgebra

# Plotsを使う際のおまじない
gr()
ENV["PLOTS_TEST"] = "true"

# 訓練データを作成
N = 500
mean1 = [-2 2]
mean2 = [1 -1]
mean3 = [8 -6]
cov = [1.0 0.8; 0.8 1.0]

# ノイズありデータ作成
cls1 = zeros(0)
for i in 1:2
    d = Normal(mean1[i], cov[i]) # mean1とcovから生成した正規分布
    append!(cls1, rand(d, div(N, 2))) # 正規分布からランダムにN/2個選択
end
cls1 = reshape(cls1, (div(N, 2), 2))

cls2 = zeros(0)
for i in 1:2
    d = Normal(mean2[i], cov[i, 2])
    append!(cls2, rand(d, div(N, 2) - div(N, 5)))
    d = Normal(mean3[i], cov[i, 2])
    append!(cls2, rand(d, div(N, 5)))
end
cls2 = reshape(cls2, (div(N, 2), 2))

# トレーニングデータXの作成
cls = vcat(cls1, cls2)
temp = ones(N)
X = hcat(temp, cls)

# ラベルTを作成
t = zeros(0)
for i in 1:div(N, 2)
    append!(t, 1.0)
end
for i in 1:div(N, 2)
    append!(t, 0.0)
end

# パラメータwをIRLSで更新
turn = 0
w = [0.0 0.0 0.0]  # 適当な初期値
while true
    phi = X

    # Rとyを計算
    R = zeros(N, N)
    y = zeros(0)
    for n in 1:N
        a = dot(w, phi[n, :])
        y_n = sigmoid(a)
        R[n, n] = y_n * (1.0 - y_n)
        append!(y, y_n)
    end
    
    # ヘッセ行列Hを計算
    phi_T = phi' #3*100
    H = phi_T * R * phi

    # wを更新
    w_new = vec(w) .- inv(H) * (phi_T * (y - t))

    # wの収束判定
    diff = norm(w_new .- w) ./ norm(w)
    println("turn:", turn)
    println("diff:", diff)
    if diff < 0.05
        break
    end
    
    w = w_new
    turn += 1
end

# %% [markdown]
# ## 入力データと識別境界の描画

# %%
#入力データの描画
x = cls[:, 1]
y = cls[:, 2]
x = reshape(x, (div(N, 2), 2))
y = reshape(y, (div(N, 2), 2))
plot(x, y, seriestype=:scatter)

# 識別境界を描画
# x1 = linspace(-6, 10, 100) linspace()は1.0では使えない
x1 = range(-6, stop=10, length=100)
x2 = [f(x, w) for x in x1]
plot!(x1, x2) # "!"をつけることでレイヤーの上書きをする
# savefig("logistic.png")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 29.4661,375.869 580.315,375.869 580.315,11.811 29.4661,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3402">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   76.9768,375.869 76.9768,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   236.58,375.869 236.58,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.183,375.869 396.183,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.786,375.869 555.786,11.811
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,304.288 580.315,304.288
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,212.641 580.315,212.641
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,120.995 580.315,120.995
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.4661,29.3479 580.315,29.3479
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,375.869 29.4661,11.811
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.9768,375.869 76.9768,370.408
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   236.58,375.869 236.58,370.408
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.183,375.869 396.183,370.408
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.786,375.869 555.786,370.408
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,304.288 37.7289,304.288
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,212.641 37.7289,212.641
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,120.995 37.7289,120.995
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.4661,29.3479 37.7289,29.3479
#   "/>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 76.9768, 389.669)" x="76.9768" y="389.669">-5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 236.58, 389.669)" x="236.58" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 396.183, 389.669)" x="396.183" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.786, 389.669)" x="555.786" y="389.669">10</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 308.788)" x="23.4661" y="308.788">-5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 217.141)" x="23.4661" y="217.141">0</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 125.495)" x="23.4661" y="125.495">5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.4661, 33.8479)" x="23.4661" y="33.8479">10</text>
# </g>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="132.826" cy="164.072" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="132.826" cy="164.072" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="180.582" cy="195.571" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="180.582" cy="195.571" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="154.356" cy="165.464" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="154.356" cy="165.464" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="141.649" cy="152.878" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="141.649" cy="152.878" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="166.688" cy="165.364" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="166.688" cy="165.364" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="163.668" cy="183.059" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="163.668" cy="183.059" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="228.949" cy="180.166" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="228.949" cy="180.166" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="136.189" cy="169.027" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="136.189" cy="169.027" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="185.301" cy="183.436" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="185.301" cy="183.436" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="153.58" cy="166.029" r="4"/>
# <circle clip-path="url(#clip3402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="153.58" cy="166.029" r="3"/>
# <circle clip-path="url(#clip3402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="178.535" cy="196.54" r="4"/>
# <circle clip-path="url
